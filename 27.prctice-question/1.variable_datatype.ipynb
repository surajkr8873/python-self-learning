# %% [markdown]
# Write a program to input 2 number & print their sum.

# %%
first = int(input("enter a number : ")) # 20
second = int(input("enter a number : ")) # 10

print("sum :" , first + second) # >> 30
# Out:
# sum : 30

# %% [markdown]
# Write a program to input sidee of a square & print its area.

# %%
#  ish baar hum float value se krenge

side = float(input("enter side : ")) # 10.2

print("side : " , side * side)
print("side : " , side ** 2)
# Out:
# side :  102.00999999999999
# side :  102.00999999999999

# %% [markdown]
# Write a program to input 2 floating point number &  print their average.

# %%
a = float(input("enter a number"))
b = float(input("enter a number"))

print("avg : ",(a + b)/2)
# Out:
# avg :  7.75

# %% [markdown]
# Write a program to input 2 numbber a and b.,,
# print True if a is greater than or equal to b, if not print False.

# %%
a = int(input("enter a number")) # 20
b = int(input("enter a number")) # 10

print(a >= b) #True
print(a <= b) #False
# Out:
# True
# False
