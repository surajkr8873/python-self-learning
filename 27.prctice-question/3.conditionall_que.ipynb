# %% [markdown]
# write  a program ifa  number entered by th user is odd or even

# %%
num = int(input("enter a number"))

if num % 2 == 0:
    print("even")

else:
    print("odd")
# Out:
# even

# %% [markdown]
# write a program to find the greatest of 3 number entered by the user

# %%
num1 = int(input("enter a number"))
num2 = int(input("enter a number"))
num3 = int(input("enter a number"))

if  num1 > num2 or num1 > num3:
    print("num1 is greater")

elif num2 > num3:
    print("num2 is greater")

else:
    print("num3 is greater")
# Out:
# num2 is greater

# %% [markdown]
# write a program to check if a number is a multiple of 7 or not

# %%
num = int(input("enter a number"))

if  num % 7 == 0:
    print("it is divisible by 7")

else:
    print("it's not divisible by 7")
# Out:
# it's not divisible by 7
