# %% [markdown]
# 1.  String ko input lo aur uski length print karo.

# %%
str = input("enter name : ")

print(len(str))
# Out:
# 11

# %% [markdown]
# 2.  String reverse karo

# %%
name = input("enter name : ")

print(name[::-1])
# Out:
# ramuk jarus

# %% [markdown]
# 3.  User se naam input lo aur first character print karo.

# %%
name = input("enter name : ")

print(name[0])
# Out:
# s

# %%
a = "suraj"
b = " kumar "

print(a+b)
# Out:
# suraj kumar
