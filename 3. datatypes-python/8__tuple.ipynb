# %% [markdown]
# What is tuple ?

# %%
# English

# A tuple is an ordered collection of multiple values that cannot be changed after it is created.

# Hindi 

# Tuple ek ordered collection hai jisme hum multiple values store kar sakte hain, lekin tuple banne ke baad uski values ko change nahi kar sakte.

# %%
# Tuple bhi ek container hai jisme hum multiple values store kar sakte hain.

# %% [markdown]
# sign of tuple

# %%
#  ()

# %%
tup = (10, 20, 30)
print(tup)
# Out:
# (10, 20, 30)

# %%
# List → Mutable
# Tuple → Immutable

tup = (10, 20, 30)

tup[1] = 200 # >> tuple ko change nahi kar skte hai isiliye output :-

# Error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       2 # Tuple → Immutable
#       3
#       4 tup = (10, 20, 30)
#       5
# ----> 6 tup[1] = 200 # >> tuple ko channge nahi kar skte hai isiliye output :-
#       7
#       8 # Error
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Jis order mein values dalte ho, wahi order maintain hota hai.

tup = (10, 20, 30, 40)

print(tup)
# Out:
# (10, 20, 30, 40)

# %% [markdown]
# chack the tuple datatype

# %%
tup = (10, 20, 30) #>>> tup

print(type(tup)) # >> jab hum kisi variable ka type check krte hai to paranthesis ke andar type ka use krte hai. :- print = syntax
                                                                                                               # type = type check karna ho to.
                                                                                                               #      = jis variable ka type check karna hai.

# %% [markdown]
# 5 Example of  tuple.

# %%
# Example 1: Simple tuple
tup = (10, 20, 30)
print(tup)


# Example 2: Indexing
tup = (10, 20, 30, 40)
print(tup[0])
print(tup[2])


# Example 3: Type check
tup = (10, 20, 30)
print(type(tup))


# Example 4: Different datatypes
tup = (10, 2.5, "Hello", True)
print(tup)


# Example 5: Immutable
tup = (10, 20, 30)

# tup[0] = 100     #  Error
print(tup)
# Out:
# (10, 20, 30)
# 10
# 30
# <class 'tuple'>
# (10, 2.5, 'Hello', True)
# (10, 20, 30)
