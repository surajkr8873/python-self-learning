# %% [markdown]
# WHAT IS  INTEGER DATATYPES ?

# %%
# English:
# (int) stands for Integer. It is used to store whole numbers, without decimal points.

# Hindi:
# (int) ka matlab Integer hota hai. Isme hum poore numbers store karte hain, decimal ke bina

# Eg :-.............. , -3, -2, -1, 0 , 1, 2, 3.......

# %%
age = 17
marks = 10
number = -5

# (upr jitne bhi value hai wo sab integer value me hai,)

# %% [markdown]
# Type check of int.>

# %%
age = 17 
print(type(age)) # jab hum kisi variable ka type check krte hai to paranthesis ke andar type ka use krte hai. :- print = syntax
                                                                                                               # type = type check karna ho to.
                                                                                                               #      = jis variable ka type check karna hai.

# %% [markdown]
# Five example of type check of int.>

# %%
age = 15
marks = 89
price = 44
rent = 2000
loss = -500
num = 0

print(type(age))
print(type(marks))
print(type(price))
print(type(rent))
print(type(loss))
print(type(num))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
# agar iska type na check krke iska value display krna ho to bina type() ko use kiye print() karna hoga.
print(age)
print(marks)
print(price)
print(rent)
print(loss)
print(num)
# Out:
# 15
# 89
# 44
# 2000
# -500
# 0
