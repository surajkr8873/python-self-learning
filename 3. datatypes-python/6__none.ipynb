# %% [markdown]
# What is None datatype ?

# %%
# English:

# None means no value or nothing.

# Hindi:

# None ka matlab hota hai koi value nahi hai ya abhi kuch bhi nahi hai.

# %%
name = None
print(name)
print(type(None)) # >> jab hum kisi variable ka type check krte hai to paranthesis ke andar type ka use krte hai. :- print = syntax
                                                                                                               # type = type check karna ho to.
                                                                                                               #      = kis variable ka type check krna hai.
# Out:
# None
# <class 'NoneType'>

# %%
a = 0 # >> 0 is number
b = None # >> None abhi iska koi value nahi hai

# %%
a = 5
b = None

c = 10
# c = b >> Error >>>> TypeError
# b = c >> isko bina # ke run krenge to datatype int hoga kyuki humne ye phle hi bata diya hai ki b jo hai wo c ke equal hai.or jo c hai wo int type hai.

# print(a + b)

print(type(b))
# Out:
# <class 'NoneType'>
