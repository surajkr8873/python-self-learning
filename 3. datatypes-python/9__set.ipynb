# %% [markdown]
# What is set.

# %%
# English 

# A set is an unordered collection of unique values.

# Hindi

# Set ek unordered collection hai jisme unique (alag-alag) values store hoti hain.

# %% [markdown]
# Easy language;

# %%
# socho ik box hai jisme hum same chij ko nahi rakh skte.


# set >>>>
# ushi tarah set hai jisme number ya kuchh bhi same nahi rakh skte hai.same datatype rakh skte hai

# %%
# set is mutable but its is in unordered.

# %% [markdown]
# sign of set.

# %%
#     {}

# %% [markdown]
# type checkinng of set.

# %%
s = {10, 20, 30}

print(type(s)) # >> jab hum kisi variable ka type check krte hai to paranthesis ke andar type ka use krte hai. :- print = syntax
                                                                                                               # type = type check karna ho to.
                                                                                                               #      = kis variable ka type check krna hai.
# Out:
# <class 'set'>

# %%
# set unordered hota hai isiliye isme indexing nahi kiya jaa skta.

s = {10, 20, 30}

print(s[0]) # >> isme Error aayega kyuki  hum set ko indexing nahi kar skte hai.

# Error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 # set unordered hota hai isiliye isme indexing nahi kiya jaa skta.
#       2
#       3 s = {10, 20, 30}
#       4
# ----> 5 print(s[0]) # >> isme Error aayega kyuki  hum set ko indexing nahi kar skte hai.
#       6
#       7 # Error
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# EXAMPLE . >>

# %%
s = {10, 20, 30}
print(s)
# Out:
# {10, 20, 30}

# %%
#  set is mutable.ik baar set ban ne ke baad hum set ko change kar skte hai.

s = {10, 20, 30}

s.add(40)

print(s)
# Out:
# {40, 10, 20, 30}

# %%
a = {1 , 2 , 3}
a[1] = 5
print(a) # Error >> because set is unordered.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 a = {1 , 2 , 3}
# ----> 2 a[1] = 5
#       3 print(a)
#
# TypeError: 'set' object does not support item assignment

# %% [markdown]
# 5 Example of set.

# %%
# Example 1: Simple Set
s = {10, 20, 30, 40}

print(s)


# Example 2: Duplicate values
s = {10, 20, 10, 30, 20}

print(s)
# Duplicate automatically remove ho jayenge


# Example 3: Type check
s = {10, 20, 30}

print(type(s))
# <class 'set'>


# Example 4: Add value
s = {10, 20, 30}

s.add(40)

print(s)


# Example 5: Remove value
s = {10, 20, 30}

s.remove(20)

print(s)
# Out:
# {40, 10, 20, 30}
# {10, 20, 30}
# <class 'set'>
# {40, 10, 20, 30}
# {10, 30}
