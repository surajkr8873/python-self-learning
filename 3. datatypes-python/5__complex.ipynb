# %% [markdown]
# What is complex datatype ?

# %%
# English:

# complex is a data type used to store complex numbers.

# Hindi:

# complex ek data type hai jisme hum complex numbers store karte hain.

# %% [markdown]
# What is complex number?

# %%
# A complex number is a number that combines a real number and an imaginary number.

# Eg :-
# 1 >>  5 + 8j >>> 5 is number,,,8j is imaginary number.
# code me hum imaginary number ko (j) se denote krte hai.

# %% [markdown]
# <!-- View allA complex number is a number that combines a real number and an imaginary number, written in the form \(a + bi\) -->

# %%
a = 5 + 8j
b = 8 - 4j
c = 5 * 7j
d = 10 / 5j

print(type(a))
print(type(b))
print(type(c))
print(type(d)) # >> jab hum kisi variable ka type check krte hai to paranthesis ke andar type ka use krte hai. :- print = syntax
                                                                                                               # type = type check karna ho to.
                                                                                                               #      = kis variable ka type check krna hai.
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
#  in sabka vlue check krna ho to to.

a = 5 + 8j
b = 8 - 4j
c = 5 * 7j
d = 10 / 5j

print(a)
print(b)
print(c)
print(d)
# Out:
# (5+8j)
# (8-4j)
# 35j
# -2j
