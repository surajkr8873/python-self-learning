# %% [markdown]
# What is boolean datattpe ?

# %%
# English:
# Boolean is a data type that has only two values: True or False.

# Hindi:
# Boolean ek data type hai jisme sirf 2 values hoti hain: True or False.

# %%
# boolean ik aisa datatype hai jo hame sahi or galat ke form me information deta hai.

# %%
student = True
raining = False
print(type(student))
print(type(raining))   # jab hum kisi variable ka type check krte hai to paranthesis ke andar type ka use krte hai. :- print = syntax
                                                                                                               # type = type check karna ho to.
                                                                                                               #      = jis variable ka type check karna hai.
# Out:
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# Iska use hum kisi 2 value ko compare krne ke liye bhi use karte hai.

# %%
# Eg :-

a = 10 # integer
b = 5  # integer

print(a > b)
print(type(a and b))
# Out:
# True
# <class 'int'>

# %%
# iska use hum bina 2 value liye bhi kar skkte hai.
# Eg :-

print(15 > 58) # False >> kyuki ye galat hai
# Out:
# False

# %%
#iska value print karwana ho to.

a = 10
b = 5

print(a)
print(b)
# Out:
# 10
# 5

# %%
#  iska jab hum (+) ya (-) ya (*) ya (/) krte hai to hum int value  ko print kr rhe hote hhai.
a = 10 
b = 5

print(a + b)
print(a - b)
print(a * b)
print(a / b)

print(type(a + b))
print(type(a - b))
print(type(a * b))
print(type(a // b))
# Out:
# 15
# 5
# 50
# 2.0
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# lekin jab compare kar rhe hote hai to hum boolean me output lete hai

# %%
a = 10 
b = 5

print(a > b)
# Out:
# True
