# %% [markdown]
# What is list datatype ?

# %%
# English:

# A list is used to store multiple values in one variable.

# Hindi:

# List ek aisa box hai jisme hum bahut saari values ek saath rakh sakte hain.

# List banane ke liye square brackets [ ] use karte hain.

# %%
# list is mutable and order form.
# mutable >> list ko change kiya jaa skta hai.
# order matlab ye ik sequence me rhta hai.jisko hum ik ik krke value ko le skte hai ya ik sath pure list ko le skte hai.

# %% [markdown]
# sign of list.

# %%
#   []

# %% [markdown]
# EXAMPLE

# %%
# >> Bag = [Pen, Book, Pencil, Eraser]

# %%
numbers = [10, 20, 30, 40, 50]

print(numbers)
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# Type checking of list.

# %%
numbers = [10, 20, 30, 40, 50]

print(type(numbers))   # jab hum kisi variable ka type check krte hai to paranthesis ke andar type ka use krte hai. :- print = syntax
                                                                                            # type = type check karna ho to.
                                                                                            #      = jis variable ka type check karna hai.
# Out:
# <class 'list'>

# %%
# list ko hum aise smjh skte hai ki hmare pass ik bag hai jisme hum bahut sa saman rkh skte hai.
# to list bhi bag ki tarah hi hai lekin list ke andar hum bahut sare datatype ko rkhte hai 

data = [10, 2.5, "Hello", True]

# 10       → int
# 2.5      → float
# "Hello"  → string
# True     → bool

# %%
# list me har item ka ik address/number hota hai.jise indexing khte hai.

# python me counting 0 se suru hoti hai.

numbers = [10, 20, 30, 40, 50]

print(numbers[0])   # 10
print(numbers[1])   # 20
print(numbers[2])   # 30
print(numbers[3])   # 40
print(numbers[4])   # 50

# Index:     0    1    2    3    4
# Value:    10   20   30   40   50
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
# list ki value ko change kar skte hai.list is mutable >> mutable means ki ushe change kar skte hai hai.

numbers = [10, 20, 30, 40]

numbers[1] = 200

print(numbers)
# Out:
# [10, 200, 30, 40]

# %% [markdown]
# Some example of list

# %%
numbers = [10, 20, 30]

print(numbers)       # [10, 20, 30]

print(numbers[0])    # 10

numbers[1] = 250     # 20 ko 200 kar diya

print(numbers)
# Out:
# [10, 20, 30]
# 10
# [10, 250, 30]

# %%
#            [] = bag
#            index = item ka address
#            value change = mutable
