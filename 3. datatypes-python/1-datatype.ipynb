# %% [markdown]
# what is datatype.

# %%
# English:
# A data type tells Python what kind of value something is.

# Hindi:
# Data type Python ko batata hai ki value kis type ki hai.

# %% [markdown]
# Types of datatype

# %%
# datatypes:

# Ten types of datatype.
# -----------------------------------
# 1. integer datatype
# 2. float datatype
# 3. string datatype
# 4. boolean datatype
# 5. complex datatype
# 6. none datatype
# 7. list datatype
# 8. tuple datatype
# 9. set datatype
# 10. dictionary datatype
