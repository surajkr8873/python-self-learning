# %%
# what is variable
# naming rules
# input
# type checking

# %% [markdown]
# WHAT IS VARIABLE

# %%
# English:
# A variable is a name used to store a value.

# Hindi:
# variable ik naam wala box hai jisme koi value store hota hai.

# Eg :- name = "suraj kumar" >> name = variable , and name me ik value store hai suraj kumar se. to hum keh skte hai ki variable me value store hote hota hai.
#       age = 17 >> age is variable and 17 is value.

# NOTE:

# 1. value jab hum A to Z tak add krte hai to hmesa quote ke andar add krenge. ("")('')('''''')
# single quote('')
# double quote("")
# triple quote('''''')

# 2. jab hum kisi value ko number me ( 0 , 9) tak store krenge to koi quote ka use NAHI krenge.

# %% [markdown]
# RULE

# %%
# 1. variable letter se start kar skte ho.
# name = "suraj"

# 2. variable underscore (_) se start kar skte ho 
# _name = "suraj"

# 3. variable me number bich ya end me add kar skte ho.
# name1aa = "suraj"
# name1 = "suraj"
 
# 4. variable ko nuumber se start nahi kar skte ho.
# 1name = "suraj"

# 5. varible me space use nh kar skte ho.
# student name = "suraj" #wrong >> space ke badle aap undeerscore(_) use kr skte ho.
#                        student_name = "suraj"

# 6. python keyword ko aap variable me use nh kar skte.
# Eg > if , print , True ,E.tc........

# python ke kuchh fixed keyword hote hai jinhe aap variable banane me use nahi kar skte hai kyuki wo phle se fix hote hai unke work ke hisab se.
# total 33 words.

# 1.and, 2.ass, 3.assert, 4.break, 5.class, 6.continue, 7.def, 8.del, 9.elif, 10.else, 11. except,

# 12.finally, 13.False, 14.for, 15.from, 16.global, 17.if, 18.import, 19.in, 20.is, 21.lambda, 22.nonlocal,

# 23.NONE, 24.not, 25.or, 26.pass, 27.raise, 28.return, 29.True, 30.try, 31.with, 32.while, 33.yield.

# %% [markdown]
# INPUT

# %%
# INPUT: >> ENGLISH
# input() is used to take information from the user.

# HINDI
# input() ka use hum tab krte hai jab hume koi data ya informationn hum kisi user se lete hai.
# input normally user ke information ko string ke form me leta hai.number me value lena ho to input ke phle int(integer) put krna pdta hai.jo hum datatype me pdhenge.

name = input("information") #input ka syntax.
print(name)
# Out:
# 55

# %% [markdown]
# TYPE_CHECKING

# %%
# English:
# Type checking means checking what type of data a value contains.

# hindi:
# type checking matlab hum jis value ko variable ke andar store kar rhe hai wo kis type ka data hai.

# type check krne ke liye jab hm value ko print karte hai to uske phle type ka use krne se ush data ka datatype pata chlta hai.

# datatypes:
# ten types of datatype.
# 1. integer datatype
# 2. float datatype
# 3. string datatype
# 4. boolean datatype
# 5. complex datatype
# 6. none datatype
# 7. list datatype
# 8. tuple datatype
# 9. set datatype
# 10. dictionary datatype

# ab datatype lesson 3 me pdhenge.
