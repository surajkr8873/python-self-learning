# %% [markdown]
# What is string ?? in python.

# %%
# English

# String is a collection of characters/text.

# Hindi

# String ka use text ya characters ko store karne ke liye hota hai.

# %%
name = "Suraj"   # >> suraj is string >> ye hmesa quotes ke andr rhta hai.

# %%
age = 18 # >>> ye int value me hai lekin isko hum quote ke anndr likhenge to string me ho jayega 

# Eg:-

age = "18"

# %% [markdown]
# Eg:-

# %%
name = "Suraj"

print(name)

# name ek variable hai.
# "Suraj" ek string hai.

# Python "Suraj" ko text samjhega.
# Out:
# Suraj

# %% [markdown]
# 5 Eg :- of string

# %%
# 1. Name
name = "Suraj"
print(name)
print(type(name))

# 2. City
city = "Patna"
print(city)
print(type(city))


# 3. Sentence
message = "Hello Bhai"
print(message)
print(type(message))


# 4. Number as a String
age = "18"
print(age)
print(type(age))

# 5. Empty String
text = "asdfghjk"
print(text)
print(type(text))
# Out:
# Suraj
# <class 'str'>
# Patna
# <class 'str'>
# Hello Bhai
# <class 'str'>
# 18
# <class 'str'>
# asdfghjk
# <class 'str'>

# %% [markdown]
# Basic humlog phle hi pdh chuke hai datatype me

# %% [markdown]
# ye dattatype hi hai lekin ish baar hum detail me pdhenge.
