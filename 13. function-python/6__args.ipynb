# %% [markdown]
# *arg in python ?

# %%
# Function mein jitne chahe arguments bhej sakte ho.

# %% [markdown]
# Normal function mein hume pehle se pata hona chahiye ki kitne arguments aayenge:

# %%
def add(a, b):
    print(a + b)

add(10, 20)

# Yahan sirf 2 arguments de sakte hain.
# Out:
# 30

# %% [markdown]
# LEKIN *ARG ME

# %%
def add(*args):  # >> arg ke jagah pr hum kuchh bhi likhe skte hai.lekin kuchh bhi likhne se phle  * ka use krenge
    print(args)

add(10, 20, 30, 40, 50)

# iska output hamesha (tuple) me aata hai
# Out:
# (10, 20, 30, 40, 50)

# %% [markdown]
# ik dum simple roop se smjhte hai

# %%
# socho tmhare pass ik bag hai jiske andar tum kitna bhi saman rakh skte ho.jisko python automatic ik value me rakh deta hai jisko tuple ke form me output deta hai.

# %% [markdown]
# *arg ka syntax

# %%
# def function_name(*args):
#      code

# %%
def numbers(*args):
    print(args)

numbers(10, 20, 30)  #>> args ke andar values tuple ban jaati hain.
# Out:
# (10, 20, 30)

# %% [markdown]
# for loop in function *arg in python.

# %%
# for loop ke saath

# *args ke andar multiple values hoti hain, isliye hum loop laga sakte hain:

def numbers(*args):

    for i in args:
        print(i)

numbers(10, 20, 30, 40)
# Out:
# 10
# 20
# 30
# 40

# %% [markdown]
# Line-by-line

# %%
# def numbers(*args):
#     jitne arguments aaye, sab args mein store honge.

# for i in args:
#     ek-ek value nikaalo.

# print(i)
#     value print karo.

# %% [markdown]
# *arg se  sum

# %%
def add(*args):

    total = 0

    for i in args:
        total = total + i

    print(total)

add(10, 20, 30, 40)
# Out:
# 100

# %% [markdown]
# sub in *arg

# %%
def sub(*arg):

    total = arg[0]

    for i in arg[1:]:
        total = total - i

    print(total)

sub(10 , 5 )
# Out:
# 5

# %% [markdown]
# 5 example of *arg function in python

# %%
# 1. Multiple names
def names(*args):
    print(args)

names("Suraj", "Rahul", "Aman")


# 2. Multiple numbers
def numbers(*args):
    for i in args:
        print(i)

numbers(10, 20, 30, 40)


# 3. Sum
def add(*args):
    total = 0

    for i in args:
        total = total + i

    print(total)

add(5, 10, 15)


# 4. Count arguments
def count(*args):
    print(len(args))
    print(type(args))

count(10, 20, 30, 40, 50)


# 5. Check type
def show(*args):
    print(type(args))

show(10, 20, 30)
# Out:
# ('Suraj', 'Rahul', 'Aman')
# 10
# 20
# 30
# 40
# 30
# 5
# <class 'tuple'>
# <class 'tuple'>

# %%
# *args = jitne chahe positional arguments lene ka tareeka.

# Aur sab arguments function ke andar tuple ban jaate hain.

# %%
def test(*args):
    print(args)

test(1, 2, 3, 4)
# Out:
# (1, 2, 3, 4)
