# %% [markdown]
# What is **kwarg function in python

# %%
# Function mein jitne chahe key=value arguments bhej sakte ho.

# %% [markdown]
# *args mein values aati hain:

# %%
# add(10, 20, 30)

# %% [markdown]
# Lekin **kwargs mein naam ke saath value aati hai:

# %%
# student(name="Suraj", age=18, city="Siwan")

# %% [markdown]
# Basic syntax

# %%
def function_name(**kwargs):
    print(kwargs)

# %% [markdown]
# Example:

# %%
def student(**kwargs): # >> kwargs ke jagah pr kuchh bhi likh skte hai lekin kuchh likhne se phle  ** denna jaruri ai
    print(kwargs)
    print(type(kwargs))

student(name="Suraj", age=18, city="patna") # >> ye hamesha dictionary ke type me aayegga
# Out:
# {'name': 'Suraj', 'age': 18, 'city': 'patna'}
# <class 'dict'>

# %% [markdown]
# simple roop se smjhte hai

# %%
# socho tmhare pass ik bag hai (**kwargs) > Is bag mein har cheez ka naam + value hai:

# name → Suraj
# age  → 18
# city → patna


#    { "name": "Suraj",
#     "age": 18,
#     "city": "patna" }

# %% [markdown]
# for loop ke saath

# %%
def student(**kwargs):

    for key, value in kwargs.items():
        print(key,"=" , value)

student(name="Suraj", age=18, city="patna")



# name = Suraj
# age = 18
# city = patna


# name , age , city >>> keys
# suraj , 18 , patna >> values
# Out:
# name = Suraj
# age = 18
# city = patna

# %% [markdown]
# 5 example.

# %%
# 1. Student details
def student(**kwargs):
    print(kwargs)

student(name="Suraj", age=18, city="Siwan")


# 2. Employee details
def employee(**kwargs):
    for key, value in kwargs.items():
        print(key, "=", value)

employee(name="Rahul", salary=20000)


# 3. Multiple details
def details(**kwargs):
    print(kwargs)

details(name="Aman", age=20, course="Python")


# 4. Count key-value pairs
def count(**kwargs):
    print(len(kwargs))

count(name="Suraj", age=18, city="Siwan")


# 5. Check type
def show(**kwargs):
    print(type(kwargs))

show(name="Suraj", age=18)
# Out:
# {'name': 'Suraj', 'age': 18, 'city': 'Siwan'}
# name = Rahul
# salary = 20000
# {'name': 'Aman', 'age': 20, 'course': 'Python'}
# 3
# <class 'dict'>

# %%
# *args = values 
# **kwargs = key + value
